# %% [markdown]
# ## Ollama Setup
#
# Visit [ollama.com](https://ollama.com) to download and install ollama.
#
# Once completed, the ollama server should already be running locally at:
# [http://localhost:11434/](http://localhost:11434/)
#
# Should see the message `Ollama is running`.

# %%
# imports
import requests
from bs4 import BeautifulSoup
from IPython.display import Markdown, display

# %%
# Constants
OLLAMA_API = "http://localhost:11434/api/chat"
HEADERS = {"Content-Type": "application/json"}
MODEL = "llama3.2"

# %%
messages = [
    {"role": "user", "content": "Describe some of the business applications of Generative AI"}
]

# %%
payload = {
        "model": MODEL,
        "messages": messages,
        "stream": False
    }

# %%
# making sure the model is loaded
# !ollama pull llama3.2
# Out:
# pulling manifest â ‹ pulling manifest â ™ pulling manifest â ¹ pulling manifest â ¸ pulling manifest â ¼ pulling manifest
# pulling dde5aa3fc5ff: 100% â–•â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–� 2.0 GB
# pulling 966de95ca8a6: 100% â–•â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–� 1.4 KB
# pulling fcc5a6bec9da: 100% â–•â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–� 7.7 KB
# pulling a70ff7e570d9: 100% â–•â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–� 6.0 KB
# pulling 56bb8bd477a5: 100% â–•â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–�   96 B
# pulling 34bb5ab01051: 100% â–•â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–�  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
response = requests.post(OLLAMA_API, json=payload, headers=HEADERS)
print(response.json()['message']['content'])
# Out:
# Generative AI has numerous business applications across various industries. Here are some examples:
#
# 1. **Content Creation**: Generative AI can be used to create high-quality content such as articles, social media posts, and product descriptions. It can also generate images, videos, and music.
# 2. **Marketing Automation**: Generative AI can help automate marketing processes by generating personalized ads, emails, and promotional materials based on customer data and behavior.
# 3. **Personalization**: Generative AI can be used to create personalized recommendations for customers, such as product suggestions, travel itineraries, or educational content.
# 4. **Chatbots and Virtual Assistants**: Generative AI can power chatbots and virtual assistants that provide 24/7 support, answer customer queries, and route complex issues to human representatives.
# 5. **Design and Prototyping**: Generative AI can be used to generate designs, prototypes, and architectural models, reducing the need for manual drafting and iteration.
# 6. **Data Analysis and Insights**: Generative AI can analyze large datasets, identify patterns, and provide actionable insights that help businesses make data-driven decisions.
# 7. **Customer Service**: Generative AI can be used to create automated customer service solutions, such as chatbots, that can handle routine queries and free up human agents for more complex issues.
# 8. **Supply Chain Optimization**: Generative AI can analyze supply chain data, predict demand, and optimize inventory levels, reducing stockouts and overstocking.
# 9. **Financial Modeling and Forecasting**: Generative AI can be used to create financial models that forecast sales, revenue, and expenses, helping businesses make more accurate predictions and decisions.
# 10. **Research and Development**: Generative AI can assist researchers in generating new ideas, testing hypotheses, and simulating complex systems, accelerating innovation and discovery.
#
# Some specific business applications of Generative AI include:
#
# * **E-commerce**: Generate product images, descriptions, and recommendations based on customer behavior and preferences.
# * **Healthcare**: Create personalized treatment plans, generate medical reports, and analyze patient data to improve diagnosis and treatment outcomes.
# * **Finance**: Develop predictive models for credit risk assessment, generate investment recommendations, and optimize portfolio management.
# * **Education**: Create personalized learning pathways, generate educational content, and assess student performance.
# * **Manufacturing**: Optimize production workflows, predict demand, and generate designs for new products.
#
# These are just a few examples of the many business applications of Generative AI. As the technology continues to evolve, we can expect to see even more innovative use cases across various industries.

# %% [markdown]
# ## Trying the ollama python package

# %%
import ollama

response = ollama.chat(model=MODEL, messages=messages)
print(response['message']['content'])
# Out:
# Generative AI has numerous business applications across various industries. Here are some examples:
#
# 1. **Content Generation**: Generative AI can be used to generate high-quality content such as:
#  * Articles and blog posts
#  * Social media posts
#  * Product descriptions
#  * Marketing materials (e.g., brochures, flyers)
# 2. **Product Design**: Generative AI can help designers create new product designs, including:
#  * Product prototypes
#  * 3D models
#  * Visualizations of product concepts
# 3. **Image and Video Generation**: Generative AI can be used to generate:
#  * High-quality images (e.g., product photography, interior design)
#  * Videos (e.g., explainer videos, promotional content)
# 4. **Music and Audio Generation**: Generative AI can create new music compositions or modify existing ones.
# 5. **Chatbots and Customer Service**: Generative AI-powered chatbots can:
#  * Respond to customer inquiries
#  * Provide personalized recommendations
# 6. **Personalization**: Generative AI can help personalize experiences for customers, such as:
#  * Tailored product recommendations
#  * Personalized marketing content
# 7. **Supply Chain Optimization**: Generative AI can be used to optimize supply chain operations, including:
#  * Demand forecasting
#  * Inventory management
# 8. **Financial Analysis and Modeling**: Generative AI can help analyze financial data and create predictive models for:
#  * Stock market predictions
#  * Financial risk assessment
# 9. **Marketing Campaigns**: Generative AI can generate new marketing campaigns or modify existing ones, including:
#  * Social media campaigns
#  * Email marketing campaigns
# 10. **Training and Education**: Generative AI can be used to create personalized learning materials, such as:
#  * Customized lesson plans
#  * Interactive educational content
#
# Some companies that are already leveraging Generative AI in their business applications include:
#
# * Google (e.g., image recognition, natural language processing)
# * Amazon (e.g., Alexa, customer service chatbots)
# * Microsoft (e.g., Azure Machine Learning, generative models for AI)
# * IBM (e.g., Watson, AI-powered content generation)
#
# These are just a few examples of the many business applications of Generative AI. As the technology continues to evolve, we can expect to see even more innovative uses across various industries.

# %% [markdown]
# ## Trying OpenAI library to connect to Ollama

# %%
from openai import OpenAI
ollama_via_openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')

response = ollama_via_openai.chat.completions.create(
    model=MODEL,
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# Generative AI has far-reaching potential in various industries, offering numerous business applications. Here are some examples:
#
# 1. **Content Generation**: Companies can harness generative AI to create content such as:
#  * News articles and blog posts
#  * Social media posts and ads
#  * Product descriptions and catalog text
#  * Book chapters and e-books
# 2. **Personalization**: Generative AI can help businesses personalize customer experiences by generating customized content, such as:
#  * Personalized product recommendations
#  * Tailored marketing messages
#  * Customized social media ads
# 3. **Chatbots and Virtual Assistants**: Generative AI enables the development of more human-like chatbots and virtual assistants that can:
#  * Respond to customer inquiries accurately
#  * Provide 24/7 support
#  * Offer personalized suggestions and recommendations
# 4. **Design and Creativity**: Generative AI can assist designers and artists by:
#  * Generating new design ideas and concepts
#  * Automating repetitive design tasks
#  * Enabling the creation of complex graphics, animations, and videos
# 5. **Data Analysis and Insights**: Generative AI algorithms can analyze large datasets to identify trends, patterns, and correlations, providing businesses with valuable insights for:
#  * Predictive maintenance and predictive analytics
#  * Risk assessment and credit scoring
#  * Customer segmentation and behavior analysis
# 6. **Language Translation**: Generative AI can help businesses communicate with customers in different languages by translating text, speech, and even entire videos.
# 7. **Image and Video Generation**: Generative AI can create realistic images and videos for:
#  * Marketing campaigns (e.g., product demonstrations, tutorials)
#  * Advertising and promotional materials
#  * Social media content
# 8. **Music and Audio Generation**: Generative AI can generate music, soundtracks, and audio effects for:
#  * Movie and TV show scores
#  * Video game soundtracks
#  * Advertisements and marketing campaigns
# 9. **Software Development**: Generative AI can assist software developers by generating code, automating testing, and even helping with debugging.
# 10. **Customer Experience**: Generative AI can help businesses create more personalized and engaging customer experiences through:
#  * Personalized product recommendations
#  * Real-time recommendations based on user behavior
#  * Proactive support and issue resolution
#
# These are just a few examples of the many business applications of Generative AI. As this technology continues to evolve, we can expect to see even more innovative uses across various industries.

# %%
# Some websites need you to use proper headers when fetching them:
# Use browser’s User-Agent, Go to: https://www.whatismybrowser.com/ , Copy the User-Agent string shown there
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:

    def __init__(self, url):
        """
        Create this Website object from the given url using the BeautifulSoup library
        """
        self.url = url
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        for irrelevant in soup.body(["script", "style", "img", "input"]):
            irrelevant.decompose()
        self.text = soup.body.get_text(separator="\n", strip=True)

# %%
cnn = Website("https://cnn.com")
print(cnn.title)
print(cnn.text)
# Out:
# Breaking News, Latest News and Videos | CNN
# CNN values your feedback
# 1. How relevant is this ad to you?
# 2. Did you encounter any technical issues?
# Video player was slow to load content
# Video content never loaded
# Ad froze or did not finish loading
# Video content did not start after ad
# Audio on ad was too loud
# Other issues
# Ad never loaded
# Ad prevented/slowed the page from loading
# Content moved around while ad loaded
# Ad was repetitive to ads I've seen previously
# Other issues
# Cancel
# Submit
# Thank You!
# Your effort and contribution in providing this feedback is much
#                                         appreciated.
# Close
# Ad Feedback
# Close icon
# US
# World
# Politics
# Business
# Health
# Entertainment
# Underscored
# Style
# Travel
# Sports
# Science
# Climate
# Weather
# Ukraine-Russia War
# Israel-Hamas War
# Games
# More
# US
# World
# Politics
# Business
# Health
# Entertainment
# Underscored
# Style
# Travel
# Sports
# Science
# Climate
# Weather
# Ukraine-Russia War
# Israel-Hamas War
# Games
# Watch
# Listen
# Live TV
# Subscribe
# Sign in
# My Account
# Settings
# Newsletters
# Topics you follow
# Sign out
# Your CNN account
# Sign in to your CNN account
# Sign in
# My Account
# Settings
# Newsletters
# Topics you follow
# Sign out
# Your CNN account
# Sign in to your CNN account
# Live TV
# Listen
# Watch
# Edition
# US
# International
# Arabic
# Español
# Edition
# US
# International
# Arabic
# Español
# US
# Crime + Justice
# World
# Africa
# Americas
# Asia
# Australia
# China
# Europe
# India
# Middle East
# United Kingdom
# Politics
# Trump
# Facts First
# CNN Polls
# 2025 Elections
# Business
# Tech
# Media
# Calculators
# Videos
# Markets
# Pre-markets
# After-Hours
# Fear & Greed
# Investing
# Markets Now
# Nightcap
# Health
# Life, But Better
# Fitness
# Food
# Sleep
# Mindfulness
# Relationships
# CNN Underscored
# Electronics
# Fashion
# Beauty
# Health & Fitness
# Home
# Reviews
# Deals
# Gifts
# Travel
# Outdoors
# Pets
# Entertainment
# Movies
# Television
# Celebrity
# Tech
# Innovate
# Foreseeable Future
# Mission: Ahead
# Work Transformed
# Innovative Cities
# Style
# Arts
# Design
# Fashion
# Architecture
# Luxury
# Beauty
# Video
# Travel
# Destinations
# Food & Drink
# Stay
# Videos
# Sports
# Pro Football
# College Football
# Basketball
# Baseball
# Soccer
# Olympics
# Hockey
# Science
# Space
# Life
# Unearthed
# Climate
# Solutions
# Weather
# Weather
# Video
# Climate
# Ukraine-Russia War
# Israel-Hamas War
# Watch
# Live TV
# CNN Headlines
# CNN Shorts
# Shows A-Z
# CNN10
# CNN Max
# CNN TV Schedules
# FlashDocs
# Listen
# CNN 5 Things
# Chasing Life with Dr. Sanjay Gupta
# The Assignment with Audie Cornish
# One Thing
# Tug of War
# CNN Political Briefing
# The Axe Files
# All There Is with Anderson Cooper
# All CNN Audio podcasts
# Games
# Daily Crossword
# Jumble Crossword
# Photo Shuffle
# Sudoblock
# Sudoku
# 5 Things Quiz
# About CNN
# Subscribe
# Photos
# Investigations
# CNN Profiles
# CNN Leadership
# CNN Newsletters
# Work for CNN
# Follow CNN
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# Trending
# Countries affected by tariffs
# Radioactive wasp nest
# Pamela Anderson and Liam Neeson
# Corporation for Public Broadcasting
# Lyme disease
# ‘Cortisol cocktail’
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# •
# For Subscribers
# For Subscribers
# Angela Weiss/AFP/Getty Images
# For Subscribers
# Big picture facts you should know about the US economy
# If news about inflation, trade, the Federal Reserve and jobs has you confused and you’re not sure what to make of the US economy, don’t worry: You’re in good company.
# Prashanth Vishwanathan/Bloomberg/Getty Images
# What could get more expensive from Trump’s massive tariff hikes
# President Donald Trump has said that tariffs won’t lead to higher prices. But the United States economy seems to disagree: Inflation, which has remained fairly tame, is slowly creeping up because of tariffs.
# •
# Video
# 2:08
# CNN
# Video
# Confused about Trump’s tit-for-tat tariffs? Here’s a simple analogy
# 2:08
# President Trump’s global tariffs - the most significant escalation America has imposed in a century — are having ripple effects across the global economy. Although reciprocal tariffs have been paused until July, China is exempt from this and is in a trade war with the US. Recently, the two countries came to an agreement to slash tariffs significantly on each other’s imports. A lot has happened over the last few months, and trade wars can be complicated to understand. To make things easier, CNN Business Reporter Anna Cooban explains with a very simple analogy.
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# •
# For Subscribers
# For Subscribers
# Al Drago/Bloomberg/Getty Images
# For Subscribers
# Trump brings his taste to the White House with paved over Rose Garden and $200M ballroom
# President Donald Trump held plenty of meetings at the White House this summer: with foreign delegations striking trade deals, Cabinet members plotting a government overhaul and industry executives seeking tariff relief.
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# The Trump administration takes an Orwellian turn
# Show all
# •
# Analysis
# Analysis
# Jim Watson/AFP/Getty Images
# Analysis
# Here’s a look at 5 reasons why critics say the president is charting an ominous path
# Back in March, President Donald Trump signed an executive order targeted at the Smithsonian Institution that began as follows: “Over the past decade, Americans have witnessed a concerted and widespread effort to rewrite our Nation’s history, replacing objective facts with a distorted narrative driven by ideology rather than truth.”
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# Trump and his allies mount a pressure campaign against US elections ahead of the midterms
# Trump is moving nuclear submarines following remarks by an ex-Russian president. Here are the subs in the US fleet
# Video
# Bolton reacts to Trump’s nuclear subs order
# 3:18
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# CNN Headlines
# - Source:
# CNN
# Watch the latest CNN Headlines
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# Photo Illustration by Jason Lancaster/CNN/Getty Images
# For Subscribers
# For some who are lonely, the reasons why are harsh, but true
# Aug 2, 2025
# TanyaLovus/iStockphoto/Getty Images
# Doritos thinks this flavor is its next ‘Cool Ranch’
# Aug 2, 2025
# Valuence Japana Inc. / Sotheby's
# Video
# Winning bidder of $10M Birkin bag wanted to inflict ‘psychological damage’ on opponents
# 2:00
# Aug 2, 2025
# Zhaodi Liao/Zernicka-Goetz Laboratory
# Lab-grown embryo models are getting more realistic. Scientists are getting more concerned
# Jul 31, 2025
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# CNN
# Video
# China brain tech rivals Musk’s Neuralink
# 1:35
# Jul 20, 2025
# LeoPatrizi/E+/Getty Images
# Having trouble experiencing joy? This may be why
# Jul 20, 2025
# AP/Getty Images/Reuters
# Analysis
# Democrats are making 2028 moves. Here’s what to know
# Jul 17, 2025
# CNN
# Video
# Dr. Sanjay Gupta exposes deepfake ads promoting fake health cures with his likeness
# 1:44
# Jul 31, 2025
# Janna Tew/Salter House
# People are wearing nightgowns anywhere but to bed
# Jul 29, 2025
# Photo Illustration by Jason Lancaster/CNN/Getty Images
# ‘Ozempic face’ may be driving a cosmetic surgery boom
# Jul 30, 2025
# Michael Peterson/GTRI
# ‘Megaflash’ lightning bolt traveled over 500 miles, setting a new record, study says
# Jul 31, 2025
# Carlo Zanella
# Fed-up Italian farmers set up mountain turnstiles to charge access to Instagram hot spots
# Jul 31, 2025
# Seraphinne Vallora
# Your favorite model? Thanks to AI, they might not be real
# Jul 31, 2025
# PATRICK T. FALLON/AFP/AFP via Getty Images
# Video
# Short flights, big pollution: the private jet problem
# 2:42
# Jul 31, 2025
# Vctor J. Blue/Bloomberg/Getty Images
# Inside 345 Park Avenue when a mass killer arrived
# Jul 29, 2025
# Kent Nishimura/Bloomberg/Getty Images
# Analysis: Donald Trump’s long history of fake history
# Jul 30, 2025
# Mike Blake/Reuters
# Starbucks is shutting down an entire line of cafes
# Jul 30, 2025
# naikon/iStockphoto/Getty Images
# What you eat may impact your lung cancer risk, according to a new study
# Jul 29, 2025
# fermate/iStockphoto/Getty Images
# Mosquitoes bite! 5 tips for making yourself less attractive to them
# Jul 30, 2025
# CNN
# Video
# How cargo ships deliver made-in-China goods to your door
# 10:26
# Jul 29, 2025
# Barry Neild/CNN
# The world’s first passenger jet was a luxurious death trap. Now it’s been brought back to life
# Jul 29, 2025
# Kayla Bartkowski/Getty Images
# For Subscribers
# Trump administration takes all-of-government approach to target transgender community
# Jul 21, 2025
# Mick Krever/CNN
# Video
# The Trump Administration says no one has died due to aid cuts. We went to the Taliban’s Afghanistan to investigate
# 15:31
# Jul 23, 2025
# FG Trade/E+/Getty Images
# Worried about Alzheimer’s? Start walking, according to a new 10-year study
# Jul 28, 2025
# Photo illustration by Ian Berry/CNN/Adobe Stock
# Extreme heat is miserable and dangerous. It’s also making us age faster
# Jul 25, 2025
# CNN
# Video
# The town wanted his farm for affordable housing. Then came the MAGA storm
# 3:53
# Jul 25, 2025
# CNN
# First on CNN
# Fighting early-stage Alzheimer’s with intensive lifestyles changes works, study finds
# Jul 29, 2025
# Tom Winger/500px/Getty Images
# This upstate New York town is a showstopper for scenery
# Jun 26, 2025
# Kyle Grillot/Reuters
# For Subscribers
# Where the next deadly flood wave could strike
# Jul 24, 2025
# Jonathan Cohen/Alamy Stock Photo
# We searched for America’s best towns to visit. Here are the top 10
# Jun 27, 2025
# CNN
# Video
# ‘It’s a type of torture’: Hear what it’s like inside ‘Alligator Alcatraz’
# 4:54
# Jul 25, 2025
# cnn
# Video
# Meat consumption levels are unsustainable. Going vegan isn’t the only answer
# 2:59
# Jul 15, 2025
# Taylar Robbins/Destination Missoula
# There’s world-class wilderness in every direction, but Missoula is far more than a gateway
# Jul 3, 2025
# Kent Nishimura/Getty Images
# For Subscribers
# The FBI prepares to leave its ‘monstrosity’ of a home – but may end up back where it started
# Jul 19, 2025
# Molly Flores/CNN Underscored
# CNN Underscored
# The 35 best fanny packs and belt bags, according to stylists and editors
# Jul 24, 2025
# Sonoma County Tourism
# What’s your favorite American town? We want to hear from you
# Jun 26, 2025
# Ian Berry, CNN
# Cycling like a pro… for a day: How amateurs measure themselves up to pros on one of the world’s toughest stages
# Jul 25, 2025
# Will Lanzoni/CNN
# ‘These mountains are still here.’ Asheville is ready for your visit
# Jun 26, 2025
# Sonoma County Tourism
# Once ‘the world’s egg basket,’ this Gold Rush-era boomtown still delivers culinary riches
# Jun 26, 2025
# Illustration by Ian Berry/CNN
# For Subscribers
# Will AI really wipe out white collar jobs? Tech insiders are split
# Jul 21, 2025
# CNN
# Video
# Why Billie Eilish insists on special rules at all her concerts
# 1:48
# Jul 18, 2025
# Molly Flores/CNN Underscored
# CNN Underscored
# The 25 best sympathy gift ideas to offer solace and support, according to etiquette experts
# Jul 23, 2025
# Rebeca Wright/CNN
# ‘It’s all still here.’ This seafaring town brings the past to life
# Jun 26, 2025
# Garrett Lockrem/Mt. Bachelor
# This outdoor paradise in Oregon vibrates with ‘go-play-all-day energy’
# Jun 26, 2025
# MEGA/GC Images/Getty Images
# The LA farmer’s market where celebrities are as plentiful as the produce
# Jul 16, 2025
# TikTok/@sed50252, CNN, TikTok/@anchxspider
# Video
# Meet the actor behind the viral ‘nothing beats a Jet2 holiday’ TikTok sound
# 1:50
# Jul 20, 2025
# CNN
# Video
# CNN reporter attempts airshow maneuvers in the Goodyear blimp
# 2:17
# Jul 27, 2025
# Suzanne Kreiter/The Boston Globe/ Getty Images
# For Subscribers
# A heartbreaking economic indicator: More people are giving up their pets
# Jul 27, 2025
# CNN
# Video
# This coffee chain overtook Starbucks in China. Now it’s open in the US
# 2:10
# Jul 23, 2025
# Michelle Rae Uy/CNN Underscored
# CNN Underscored
# The best personal item bags in 2025, tested and reviewed
# Jul 20, 2025
# Elva Etienne/Moment RF/Getty Images
# Analysis
# Don’t give children under age 13 smartphones, new research says
# Jul 21, 2025
# CNN
# Video
# This 6-pound backpack changed one man’s approach to life
# 2:56
# Jul 9, 2025
# Rodrigo Abd/AP
# For the first time in modern history a capital city is on the verge of running dry
# Jul 19, 2025
# US Immigration and Customs Enforcement
# Americans largely oppose Trump’s ramp-up of deportations, CNN poll finds
# Jul 20, 2025
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# For Subscribers
# •
# For Subscribers
# For Subscribers
# Illustration by Leah Abucayan/CNN/Courtesy of Marianne Ok Nielsen and Han Tae-soon
# For Subscribers
# Korean adoptees discover the depths of deceit that saw them ‘exported’ as babies
# •
# For Subscribers
# For Subscribers
# Carlos Reyes/AFP/Getty Images
# For Subscribers
# US support for Israel’s actions in Gaza drops, as Democratic opposition grows and MAGA movement splits
# •
# For Subscribers
# For Subscribers
# Chip Somodevilla/Getty Images
# For Subscribers
# Small businesses helped build Musk’s empire. Their unpaid bills add up to millions
# Ad Feedback
# Ad Feedback
# CNN Underscored
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# Best-in-class
# Kyle Olsen/CNN Underscored
# We tested 7 of the most popular suitcases for weeks and found 3 clear winners
# No umbrella, no problem. Here are 2 rain jackets that really work
# I trekked through REI’s sale section to find 10 outdoor deals worth buying
# After 40, I swapped bikinis for swimsuits that actually flatter. Here are the best ones
# 23 best body oils for younger-looking skin all over, according to dermatologists and editors
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# Expert-backed guides
# Maxwell Shukuya/CNN Underscored
# Messy ride? Here’s how to clean your car’s interior, per detailing experts
# I tested this beloved brand’s comfy $64 Align High-Rise Shorts against a $25 Quince pair
# Leave the AC off this summer. Try one of these powerful cooling tower fans instead
# The 17 best outdoor rugs to instantly upgrade your patio, according to experts
# This cat backpack has changed my life as a cat mom. Here’s why
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# Editors' picks
# Emily Pennington/CNN Underscored
# 19 best sandals for walking all day long, according to podiatrists
# Patagonia’s best-tested Nano Puff jacket, along with tons of other gear, is up to 42% off
# These Oxo products are the unsung heroes of our editors’ kitchens
# We found the best over-ear headphones after years of testing
# The Chase Sapphire Reserve just raised its annual fee to $795. This is why I’m keeping it
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# CNN Sports
# Patrick McDermott/Getty Images
# ‘It’s super disrespectful’: WNBA players exasperated after sex toy thrown onto court for 2nd time in a week
# CNN Exclusive
# He fled his hometown in Ukraine after Russia’s invasion. He never thought he’d become a world champion swimmer
# Katie Ledecky ends Summer McIntosh’s bid for Michael Phelps record
# South Korea soccer star Son Heung-min to leave Tottenham Hotspur
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# Bleacher Report
# Show all
# Lakers sign Luka Doncic to $165M deal after viral cover shoot
# Watch: NASCAR racetrack transforms into MLB field
# Video: Eminem posts ‘Happy Gilmore 2’ outtakes from viral scene
# 5 landing spots for Micah Parsons after shocking trade request
# Everything to know before WWE SummerSlam
# Ad Feedback
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# CNN Games + Quizzes
# Show all
# •
# Today's crossword
# Today's crossword
# CNN
# Today's crossword
# No pencil or eraser required
# •
# Sudoblock
# Sudoblock
# CNN
# Sudoblock
# Sudoku + Blocks = addictive tile-matching puzzle
# •
# Jumble Crossword
# Jumble Crossword
# CNN
# Jumble Crossword
# Test your smarts with this scrambled word game
# •
# Weekly news quiz
# Weekly news quiz
# cnn
# Weekly news quiz
# What do you remember from the week that was?
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# US
# Pool/Getty Images
# Convicted Idaho murderer Bryan Kohberger moved to solitary confinement, KTVB reports
# •
# Video
# 3:17
# CNN
# Video
# In a city prone to natural disasters, this famous museum uses thoughtful design and hidden tech to keep staff and artworks safe
# 3:17
# Etienne Laurent/AFP/Getty Images
# Appeals court keeps order blocking Trump administration from indiscriminate immigration sweeps
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
#

# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# Father of Georgia school shooter had letter from son ‘asking for forgiveness’ on day of the shooting, testimony reveals
# Alabama state contractor arrested after the hot-car death of a toddler she was caring for, police say
# South Korea’s jailed ex-leader Yoon resists questioning by taking off clothes
# Former Colombian President Álvaro Uribe sentenced to 12 years of house arrest
# Office cleaner who came face-to-face with the Manhattan gunman details his deadly rampage
# Apartment block strike marks the deadliest attack on Ukraine’s capital since 2024
# Subscribe
# Sign in
# My Account
# Settings
# Newsletters
# Topics you follow
# Sign out
# Your CNN account
# Sign in to your CNN account
# Live TV
# Listen
# Watch
# US
# Crime + Justice
# World
# Africa
# Americas
# Asia
# Australia
# China
# Europe
# India
# Middle East
# United Kingdom
# Politics
# Trump
# Facts First
# CNN Polls
# 2025 Elections
# Business
# Tech
# Media
# Calculators
# Videos
# Markets
# Pre-markets
# After-Hours
# Fear & Greed
# Investing
# Markets Now
# Nightcap
# Health
# Life, But Better
# Fitness
# Food
# Sleep
# Mindfulness
# Relationships
# CNN Underscored
# Electronics
# Fashion
# Beauty
# Health & Fitness
# Home
# Reviews
# Deals
# Gifts
# Travel
# Outdoors
# Pets
# Entertainment
# Movies
# Television
# Celebrity
# Tech
# Innovate
# Foreseeable Future
# Mission: Ahead
# Work Transformed
# Innovative Cities
# Style
# Arts
# Design
# Fashion
# Architecture
# Luxury
# Beauty
# Video
# Travel
# Destinations
# Food & Drink
# Stay
# News
# Videos
# Sports
# Pro Football
# College Football
# Basketball
# Baseball
# Soccer
# Olympics
# Hockey
# Science
# Space
# Life
# Unearthed
# Climate
# Solutions
# Weather
# Weather
# Video
# Climate
# Ukraine-Russia War
# Israel-Hamas War
# Watch
# Live TV
# CNN Headlines
# CNN Shorts
# Shows A-Z
# CNN10
# CNN Max
# CNN TV Schedules
# FlashDocs
# Listen
# CNN 5 Things
# Chasing Life with Dr. Sanjay Gupta
# The Assignment with Audie Cornish
# One Thing
# Tug of War
# CNN Political Briefing
# The Axe Files
# All There Is with Anderson Cooper
# All CNN Audio podcasts
# Games
# Daily Crossword
# Jumble Crossword
# Photo Shuffle
# Sudoblock
# Sudoku
# 5 Things Quiz
# About CNN
# Subscribe
# Photos
# Investigations
# CNN Profiles
# CNN Leadership
# CNN Newsletters
# Work for CNN
# Watch
# Listen
# Live TV
# Follow CNN
# Subscribe
# Sign in
# My Account
# Settings
# Newsletters
# Topics you follow
# Sign out
# Your CNN account
# Sign in to your CNN account
# Terms of Use
# Privacy Policy
# Ad Choices
# Accessibility & CC
# About
# Subscribe
# Newsletters
# Transcripts
# Help Center
# © 2025 Cable News Network. A Warner Bros. Discovery Company. All Rights Reserved.
# CNN Sans ™ & © 2016 Cable News Network.

# %% [markdown]
# ## Creating prompts
# **A system prompt** that tells them what task they are performing and what tone they should use \
# **A user prompt** -- the conversation starter that they should reply to

# %%
system_prompt = "You are an assistant that analyzes the contents of a website \
and provides a very short summary, ignoring text that might be navigation related. \
Respond in markdown."

# %%
# Function to write a User Prompt that asks for summaries of websites:

def user_prompt_for(website):
    user_prompt = f"You are looking at a website titled {website.title}"
    user_prompt += "\nThe contents of this website is as follows; \
please provide a short summary of this website in markdown. \
If it includes news or announcements, then summarize these too.\n\n"
    user_prompt += website.text
    return user_prompt

# %%
print(user_prompt_for(cnn))
# Out:
# You are looking at a website titled Breaking News, Latest News and Videos | CNN
# The contents of this website is as follows; please provide a short summary of this website in markdown. If it includes news or announcements, then summarize these too.
#
# CNN values your feedback
# 1. How relevant is this ad to you?
# 2. Did you encounter any technical issues?
# Video player was slow to load content
# Video content never loaded
# Ad froze or did not finish loading
# Video content did not start after ad
# Audio on ad was too loud
# Other issues
# Ad never loaded
# Ad prevented/slowed the page from loading
# Content moved around while ad loaded
# Ad was repetitive to ads I've seen previously
# Other issues
# Cancel
# Submit
# Thank You!
# Your effort and contribution in providing this feedback is much
#                                         appreciated.
# Close
# Ad Feedback
# Close icon
# US
# World
# Politics
# Business
# Health
# Entertainment
# Underscored
# Style
# Travel
# Sports
# Science
# Climate
# Weather
# Ukraine-Russia War
# Israel-Hamas War
# Games
# More
# US
# World
# Politics
# Business
# Health
# Entertainment
# Underscored
# Style
# Travel
# Sports
# Science
# Climate
# Weather
# Ukraine-Russia War
# Israel-Hamas War
# Games
# Watch
# Listen
# Live TV
# Subscribe
# Sign in
# My Account
# Settings
# Newsletters
# Topics you follow
# Sign out
# Your CNN account
# Sign in to your CNN account
# Sign in
# My Account
# Settings
# Newsletters
# Topics you follow
# Sign out
# Your CNN account
# Sign in to your CNN account
# Live TV
# Listen
# Watch
# Edition
# US
# International
# Arabic
# Español
# Edition
# US
# International
# Arabic
# Español
# US
# Crime + Justice
# World
# Africa
# Americas
# Asia
# Australia
# China
# Europe
# India
# Middle East
# United Kingdom
# Politics
# Trump
# Facts First
# CNN Polls
# 2025 Elections
# Business
# Tech
# Media
# Calculators
# Videos
# Markets
# Pre-markets
# After-Hours
# Fear & Greed
# Investing
# Markets Now
# Nightcap
# Health
# Life, But Better
# Fitness
# Food
# Sleep
# Mindfulness
# Relationships
# CNN Underscored
# Electronics
# Fashion
# Beauty
# Health & Fitness
# Home
# Reviews
# Deals
# Gifts
# Travel
# Outdoors
# Pets
# Entertainment
# Movies
# Television
# Celebrity
# Tech
# Innovate
# Foreseeable Future
# Mission: Ahead
# Work Transformed
# Innovative Cities
# Style
# Arts
# Design
# Fashion
# Architecture
# Luxury
# Beauty
# Video
# Travel
# Destinations
# Food & Drink
# Stay
# Videos
# Sports
# Pro Football
# College Football
# Basketball
# Baseball
# Soccer
# Olympics
# Hockey
# Science
# Space
# Life
# Unearthed
# Climate
# Solutions
# Weather
# Weather
# Video
# Climate
# Ukraine-Russia War
# Israel-Hamas War
# Watch
# Live TV
# CNN Headlines
# CNN Shorts
# Shows A-Z
# CNN10
# CNN Max
# CNN TV Schedules
# FlashDocs
# Listen
# CNN 5 Things
# Chasing Life with Dr. Sanjay Gupta
# The Assignment with Audie Cornish
# One Thing
# Tug of War
# CNN Political Briefing
# The Axe Files
# All There Is with Anderson Cooper
# All CNN Audio podcasts
# Games
# Daily Crossword
# Jumble Crossword
# Photo Shuffle
# Sudoblock
# Sudoku
# 5 Things Quiz
# About CNN
# Subscribe
# Photos
# Investigations
# CNN Profiles
# CNN Leadership
# CNN Newsletters
# Work for CNN
# Follow CNN
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# Trending
# Countries affected by tariffs
# Radioactive wasp nest
# Pamela Anderson and Liam Neeson
# Corporation for Public Broadcasting
# Lyme disease
# ‘Cortisol cocktail’
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# •
# For Subscribers
# For Subscribers
# Angela Weiss/AFP/Getty Images
# For Subscribers
# Big picture facts you should know about the US economy
# If news about inflation, trade, the Federal Reserve and jobs has you confused and you’re not sure what to make of the US economy, don’t worry: You’re in good company.
# Prashanth Vishwanathan/Bloomberg/Getty Images
# What could get more expensive from Trump’s massive tariff hikes
# President Donald Trump has said that tariffs won’t lead to higher prices. But the United States economy seems to disagree: Inflation, which has remained fairly tame, is slowly creeping up because of tariffs.
# •
# Video
# 2:08
# CNN
# Video
# Confused about Trump’s tit-for-tat tariffs? Here’s a simple analogy
# 2:08
# President Trump’s global tariffs - the most significant escalation America has imposed in a century — are having ripple effects across the global economy. Although reciprocal tariffs have been paused until July, China is exempt from this and is in a trade war with the US. Recently, the two countries came to an agreement to slash tariffs significantly on each other’s imports. A lot has happened over the last few months, and trade wars can be complicated to understand. To make things easier, CNN Business Reporter Anna Cooban explains with a very simple analogy.
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# •
# For Subscribers
# For Subscribers
# Al Drago/Bloomberg/Getty Images
# For Subscribers
# Trump brings his taste to the White House with paved over Rose Garden and $200M ballroom
# President Donald Trump held plenty of meetings at the White House this summer: with foreign delegations striking trade deals, Cabinet members plotting a government overhaul and industry executives seeking tariff relief.
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# The Trump administration takes an Orwellian turn
# Show all
# •
# Analysis
# Analysis
# Jim Watson/AFP/Getty Images
# Analysis
# Here’s a look at 5 reasons why critics say the president is charting an ominous path
# Back in March, President Donald Trump signed an executive order targeted at the Smithsonian Institution that began as follows: “Over the past decade, Americans have witnessed a concerted and widespread effort to rewrite our Nation’s history, replacing objective facts with a distorted narrative driven by ideology rather than truth.”
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
#
# FG Trade/E+/Getty Images
# Worried about Alzheimer’s? Start walking, according to a new 10-year study
# Jul 28, 2025
# Photo illustration by Ian Berry/CNN/Adobe Stock
# Extreme heat is miserable and dangerous. It’s also making us age faster
# Jul 25, 2025
# CNN
# Video
# The town wanted his farm for affordable housing. Then came the MAGA storm
# 3:53
# Jul 25, 2025
# CNN
# First on CNN
# Fighting early-stage Alzheimer’s with intensive lifestyles changes works, study finds
# Jul 29, 2025
# Tom Winger/500px/Getty Images
# This upstate New York town is a showstopper for scenery
# Jun 26, 2025
# Kyle Grillot/Reuters
# For Subscribers
# Where the next deadly flood wave could strike
# Jul 24, 2025
# Jonathan Cohen/Alamy Stock Photo
# We searched for America’s best towns to visit. Here are the top 10
# Jun 27, 2025
# CNN
# Video
# ‘It’s a type of torture’: Hear what it’s like inside ‘Alligator Alcatraz’
# 4:54
# Jul 25, 2025
# cnn
# Video
# Meat consumption levels are unsustainable. Going vegan isn’t the only answer
# 2:59
# Jul 15, 2025
# Taylar Robbins/Destination Missoula
# There’s world-class wilderness in every direction, but Missoula is far more than a gateway
# Jul 3, 2025
# Kent Nishimura/Getty Images
# For Subscribers
# The FBI prepares to leave its ‘monstrosity’ of a home – but may end up back where it started
# Jul 19, 2025
# Molly Flores/CNN Underscored
# CNN Underscored
# The 35 best fanny packs and belt bags, according to stylists and editors
# Jul 24, 2025
# Sonoma County Tourism
# What’s your favorite American town? We want to hear from you
# Jun 26, 2025
# Ian Berry, CNN
# Cycling like a pro… for a day: How amateurs measure themselves up to pros on one of the world’s toughest stages
# Jul 25, 2025
# Will Lanzoni/CNN
# ‘These mountains are still here.’ Asheville is ready for your visit
# Jun 26, 2025
# Sonoma County Tourism
# Once ‘the world’s egg basket,’ this Gold Rush-era boomtown still delivers culinary riches
# Jun 26, 2025
# Illustration by Ian Berry/CNN
# For Subscribers
# Will AI really wipe out white collar jobs? Tech insiders are split
# Jul 21, 2025
# CNN
# Video
# Why Billie Eilish insists on special rules at all her concerts
# 1:48
# Jul 18, 2025
# Molly Flores/CNN Underscored
# CNN Underscored
# The 25 best sympathy gift ideas to offer solace and support, according to etiquette experts
# Jul 23, 2025
# Rebeca Wright/CNN
# ‘It’s all still here.’ This seafaring town brings the past to life
# Jun 26, 2025
# Garrett Lockrem/Mt. Bachelor
# This outdoor paradise in Oregon vibrates with ‘go-play-all-day energy’
# Jun 26, 2025
# MEGA/GC Images/Getty Images
# The LA farmer’s market where celebrities are as plentiful as the produce
# Jul 16, 2025
# TikTok/@sed50252, CNN, TikTok/@anchxspider
# Video
# Meet the actor behind the viral ‘nothing beats a Jet2 holiday’ TikTok sound
# 1:50
# Jul 20, 2025
# CNN
# Video
# CNN reporter attempts airshow maneuvers in the Goodyear blimp
# 2:17
# Jul 27, 2025
# Suzanne Kreiter/The Boston Globe/ Getty Images
# For Subscribers
# A heartbreaking economic indicator: More people are giving up their pets
# Jul 27, 2025
# CNN
# Video
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# Week in Review
# Yoan Valat/Pool/AP
# A Tour de France kiss. Trump makes deal with European leaders. The week in photos
# •
# Quiz
# Quiz
# AP/NASA/WCCO/Catherine Ridley
# Quiz
# 7.7% of readers who took this week’s news quiz got a perfect score
# •
# Look of the Week
# Look of the Week
# Wiktor Szymanowicz/Anadolu Agency/Getty Images
# Look of the Week
# Lindsay Lohan’s premiere look is an ode to millennial nostalgia
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# For Subscribers
# •
# For Subscribers
# For Subscribers
# Illustration by Leah Abucayan/CNN/Courtesy of Marianne Ok Nielsen and Han Tae-soon
# For Subscribers
# Korean adoptees discover the depths of deceit that saw them ‘exported’ as babies
# •
# For Subscribers
# For Subscribers
# Carlos Reyes/AFP/Getty Images
# For Subscribers
# US support for Israel’s actions in Gaza drops, as Democratic opposition grows and MAGA movement splits
# •
# For Subscribers
# For Subscribers
# Chip Somodevilla/Getty Images
# For Subscribers
# Small businesses helped build Musk’s empire. Their unpaid bills add up to millions
# Ad Feedback
# Ad Feedback
# CNN Underscored
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# Best-in-class
# Kyle Olsen/CNN Underscored
# We tested 7 of the most popular suitcases for weeks and found 3 clear winners
# No umbrella, no problem. Here are 2 rain jackets that really work
# I trekked through REI’s sale section to find 10 outdoor deals worth buying
# After 40, I swapped bikinis for swimsuits that actually flatter. Here are the best ones
# 23 best body oils for younger-looking skin all over, according to dermatologists and editors
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# Expert-backed guides
# Maxwell Shukuya/CNN Underscored
# Messy ride? Here’s how to clean your car’s interior, per detailing experts
# I tested this beloved brand’s comfy $64 Align High-Rise Shorts against a $25 Quince pair
# Leave the AC off this summer. Try one of these powerful cooling tower fans instead
# The 17 best outdoor rugs to instantly upgrade your patio, according to experts
# This cat backpack has changed my life as a cat mom. Here’s why
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# Editors' picks
# Emily Pennington/CNN Underscored
# 19 best sandals for walking all day long, according to podiatrists
# Patagonia’s best-tested Nano Puff jacket, along with tons of other gear, is up to 42% off
# These Oxo products are the unsung heroes of our editors’ kitchens
# We found the best over-ear headphones after years of testing
# The Chase Sapphire Reserve just raised its annual fee to $795. This is why I’m keeping it
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# CNN Sports
# Patrick McDermott/Getty Images
# ‘It’s super disrespectful’: WNBA players exasperated after sex toy thrown onto court for 2nd time in a week
# CNN Exclusive
# He fled his hometown in Ukraine after Russia’s invasion. He never thought he’d become a world champion swimmer
# Katie Ledecky ends Summer McIntosh’s bid for Michael Phelps record
# South Korea soccer star Son Heung-min to leave Tottenham Hotspur
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# Bleacher Report
# Show all
# Lakers sign Luka Doncic to $165M deal after viral cover shoot
# Watch: NASCAR racetrack transforms into MLB field
# Video: Eminem posts ‘Happy Gilmore 2’ outtakes from viral scene
# 5 landing spots for Micah Parsons after shocking trade request
# Everything to know before WWE SummerSlam
# Ad Feedback
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# CNN Games + Quizzes
# Show all
# •
# Today's crossword
# Today's crossword
# CNN
# Today's crossword
# No pencil or eraser required
# •
# Sudoblock
# Sudoblock
# CNN
# Sudoblock
# Sudoku + Blocks = addictive tile-matching puzzle
# •
# Jumble Crossword
# Jumble Crossword
# CNN
# Jumble Crossword
# Test your smarts with this scrambled word game
# •
# Weekly news quiz
# Weekly news quiz
# cnn
# Weekly news quiz
# What do you remember from the week that was?
# info
# The top numbered articles will be viewable to readers when programmed onto a page. Make sure you have 30 or more cards added to the container for the machine learning (ML) feature to work. Your queued up articles, seen in the violet section, will use ML to surface up relevant content to the reader based on their individual interests and preferences.
# %%
def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_for(website)}
    ]

# %%
# messages_for(cnn)

# %%
response = ollama.chat(model=MODEL, messages=messages_for(cnn))
print(response['message']['content'])
# Out:
# This appears to be a list of articles and news stories from CNN.com, organized by category. Here is a brief summary of each section:
#
# **Entertainment and Culture**: Articles about the latest news in the entertainment industry, including behind-the-scenes photos of the Grateful Dead, the death of Texas accordionist Flaco Jimenez, and Sarah Jessica Parker's announcement about the final season of "And Just Like That...".
#
# **Latest Politics**: News stories about politics, including a report on a plan to slash FEMA security funding, a redrawn congressional map that could take 5 Democratic seats, and controversy surrounding Epstein files at first lawmaker town halls.
#
# **Business and Economy**: Articles about business and economic news, including billions of dollars being poured into new US manufacturing, the impact of Trump's tariffs on African countries, and a list of countries affected by the tariffs.
#
# **Health and Wellness**: News stories about health and wellness, including warnings about common allergy medication risks and restrictions on certain vaccine advisers to the CDC.
#
# **Travel and Tourism**: Articles about travel and tourism, including an increase in entry fees for visitors to the EU, the relocation of an American woman to Bali, and a list of 20 great American dishes.
#
# **Science and Discovery**: News stories about science and discovery, including a "black goo" oozing from a ship on the Great Lakes teeming with life, a modern potato evolving from a wild tomato fling 9 million years ago, and a new species of giant stick insect discovered in Australia.
#
# **World**: Articles about global news, including a US envoy visiting Gaza aid distribution site as starvation crisis deepens, an eruption at Indonesia's Mount Lewotobi Laki Laki spewing ash plumes miles away, and watches stolen from Keanu Reeves ending up in the hands of a gang in Chile.
#
# **Business and Economy**
#
# * Drugmakers are pouring billions of dollars into new US manufacturing. It still won’t achieve all of Trump’s tariff goals
# * These are the countries affected by Trump’s latest tariffs
# * Trump’s tariffs are sending African countries into China’s hands
#
# **Health and Wellness**
#
# * Experts: Common allergy medication’s risks outweigh its usefulness
# * HHS further constrains certain vaccine advisers to the CDC, limiting their input in evidence reviews

# %%
def summarize(url):
    website = Website(url)
    response = ollama.chat(model=MODEL, messages=messages_for(website))
    return response['message']['content']

# %%
summarize("https://cnn.com")
# Out:
# 'Here are some of the top headlines from CNN:\n\n**Breaking News**\n\n* Grand Canyon fire doubles in size and becomes a megafire\n* Apartment block strike marks deadliest attack on Ukraine\'s capital since 2024\n* Former Colombian President Álvaro Uribe sentenced to 12 years of house arrest\n* US envoy visits Gaza aid distribution site as starvation crisis deepens\n\n**Politics**\n\n* Trump announces new tariffs on African countries\n* Alabama state contractor arrested after hot-car death of toddler she was caring for, police say\n* South Korea\'s jailed ex-leader Yoon resists questioning by taking off clothes\n* Former President Barack Obama visits Tennessee to promote voting rights\n\n**Business**\n\n* Drugmakers invest billions in new US manufacturing, but still won\'t meet Trump\'s tariff goals\n* Watch as the stock market reacts to news of the Grand Canyon fire\n\n**Health and Wellness**\n\n* Experts warn that common allergy medication\'s risks outweigh its usefulness\n* New study finds link between air pollution and increased risk of Alzheimer\'s disease\n\n**Travel and Tourism**\n\n* EU nearly triples entry fee for visitors, but it\'s not done yet\n* American woman relocates to Bali after finding a sense of community\n\n**Entertainment and Culture**\n\n* Behind-the-scenes photos of the Grateful Dead in their early years revealed\n* Sarah Jessica Parker announces emotional and poetic end to "And Just Like That..."\n* Gary Miller, Texas accordionist who expanded popularity of conjunto and Tejano music, dies at 86\n\nThese are just a few examples of the many headlines available on CNN.'

# %%
# Function to display nice Jupyter output, using markdown
def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
display_summary("https://cnn.com")
# Out:
# This appears to be the homepage of CNN's website, with a variety of sections and topics listed across the top and sides of the page. Here are some of the key headlines and features:
#
# **Top Stories**
#
# * "Grand Canyon Blaze Doubles in Size"
# * "Father of Georgia School Shooter Had Letter from Son Asking for Forgiveness"
# * "Ukraine-Russia War: Latest Developments"
#
# **Politics**
#
# * "Trump's Tariffs Sending African Countries into China's Hands"
# * "FEMA to Release Nearly $1B in Security Funding After CNN Report on Plan"
# * "Former Colombian President Álvaro Uribe Sentenced to 12 Years of House Arrest"
#
# **Business and Economy**
#
# * "Drugmakers Pouring Billions into New US Manufacturing, But It Won't Achieve All of Trump's Tariff Goals"
#
# **Entertainment and Culture**
#
# * "Behind-the-Scenes Photos of the Grateful Dead in Their Early Years"
# * "Gary Miller, Texas Accordionist Who Expanded Popularity of Conjunto and Tejano Music, Dies at 86"
#
# **Health and Wellness**
#
# * "Experts: Common Allergy Medication's Risks Outweigh Its Usefulness"
#
# **Travel and Tourism**
#
# * "EU Nearly Triples Entry Fee for Visitors Before It Even Starts"
# * "American Food: 20 of the Greatest Dishes"
#
# **Science and Discovery**
#
# * "Modern Potato Evolved from Wild Tomato Fling 9 Million Years Ago, Scientists Say"
# * "Researchers in Australia Discover New Supersized Species of Stick Insect"
#
# **World News**
#
# * "US Envoy Visits Gaza Aid Distribution Site as Starvation Crisis Deepens"
# * "Indonesia's Mount Lewotobi Laki Laki Erupts Again, Spewing Giant Ash Plumes Miles Away"
#
# **More from CNN**
#
# * "Crypto Attack on OnlyFans Streamer Caught on Camera"
# * "Lin Chao: Grand Canyon Blaze Doubles in Size and Becomes Megafire"
#
# There are also various sections and topics listed across the top and sides of the page, including:
#
# * **CNN Polls**: A section that provides the latest polls and election news.
# * **2025 Elections**: A section that provides coverage of the 2025 elections.
# * **Business**: A section that provides the latest business news and market analysis.
# * **Tech**: A section that provides the latest technology news and innovation coverage.
# * **Fashion**: A section that provides fashion news and style advice.
#
# Overall, this is a comprehensive overview of current events and topics from around the world.

# %%
display_summary("https://anthropic.com")
# Out:
# **Overview**
# Anthropic is a company that builds AI models for human benefit, aiming to serve humanity's long-term well-being. Their flagship model Claude enables building AI-powered applications and custom experiences.
#
# **Announcements**
#
# * Claude Opus 4, their most intelligent AI model, is now available.
# * Claude Sonnet 4 and Haiku 3.5 are powerful new models that push the frontier for coding and AI agents.
# * Anthropic's ISO 42001 certification has been announced, demonstrating their commitment to quality.
#
# **Research**
#
# * Anthropic focuses on building tools with human benefit at their foundation, like Claude.
# * They have views on AI Safety and a Responsible Scaling Policy in place.
# * The Model Context Protocol has been introduced to improve model interpretability.
#
# **Products**
#
# * Claude is available for download as an app or through the API Platform.
# * Claude Code enables building custom experiences using Claude's models.
# * Anthropic Academy provides resources for learning to build with Claude.
